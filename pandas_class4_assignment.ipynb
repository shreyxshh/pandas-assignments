# %% [markdown]
# # Pandas Class 4 Assignment

# %% [markdown]
# # Q1. Select Single Column
#
# ## Problem Statement
# Create a DataFrame and display only the Name column.
#
# ## Sample Input
# ```python
# Name, Age
# ```
#
# ## Sample Output
# ```python
# Only Name column
# ```

# %%
# Write your code here
import pandas as pd

df = pd.DataFrame({
    'Name' : ['shreyash','aryan','honey'],
    'age' : [20, 21, 19]
})
print(df['Name'])
# Out:
# 0    shreyash
# 1       aryan
# 2       honey
# Name: Name, dtype: str

# %% [markdown]
# # Q2. Select Multiple Columns
#
# ## Problem Statement
# Display Name and Marks columns from a DataFrame.
#
# ## Sample Input
# ```python
# Name, Marks
# ```
#
# ## Sample Output
# ```python
# Selected columns
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['shreyash','aryan','honey'],
    'Marks' : [80, 71, 99]
})
print(df[['Name', 'Marks']])
# Out:
#        Name  Marks
# 0  shreyash     80
# 1     aryan     71
# 2     honey     99

# %% [markdown]
# # Q3. Filter Students
#
# ## Problem Statement
# Display students with Marks greater than 80.
#
# ## Sample Input
# ```python
# Marks > 80
# ```
#
# ## Sample Output
# ```python
# Filtered rows
# ```

# %%
# Write your code here
#inner bracket will return the boolean indexing and outer bracket will print the indexing
print(df[df['Marks'] > 80])
# Out:
#     Name  Marks
# 2  honey     99

# %% [markdown]
# # Q4. Filter by City
#
# ## Problem Statement
# Display students belonging to Bhopal.
#
# ## Sample Input
# ```python
# City = Bhopal
# ```
#
# ## Sample Output
# ```python
# Matching rows
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'name' : ['shreyash','aryan','rahul','ayan','ani'],
    'city' : ['bhopal', 'indore', 'bhopal', 'vidisha', 'bhopal']
})
print(df[df['city'] == 'bhopal'])
# Out:
#        name    city
# 0  shreyash  bhopal
# 2     rahul  bhopal
# 4       ani  bhopal

# %% [markdown]
# # Q5. Find Maximum Marks
#
# ## Problem Statement
# Find the highest marks from a DataFrame.
#
# ## Sample Input
# ```python
# Marks column
# ```
#
# ## Sample Output
# ```python
# Highest value
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['shreyash','aryan','honey'],
    'Marks' : [80, 71, 99],
    'Age' : [19, 20 ,24]
})
print(df['Marks'].max())
# Out:
# 99

# %% [markdown]
# # Q6. Find Minimum Age
#
# ## Problem Statement
# Find the minimum age.
#
# ## Sample Input
# ```python
# Age column
# ```
#
# ## Sample Output
# ```python
# Minimum age
# ```

# %%
# Write your code here
print(df['Age'].min())
# Out:
# 19

# %% [markdown]
# # Q7. Sort Data
#
# ## Problem Statement
# Sort students by Marks.
#
# ## Sample Input
# ```python
# Marks column
# ```
#
# ## Sample Output
# ```python
# Sorted DataFrame
# ```

# %%
# Write your code here
print(df.sort_values(by='Marks'))
# Out:
#        Name  Marks  Age
# 1     aryan     71   20
# 0  shreyash     80   19
# 2     honey     99   24

# %% [markdown]
# # Q8. Value Counts
#
# ## Problem Statement
# Count occurrences of each city.
#
# ## Sample Input
# ```python
# City column
# ```
#
# ## Sample Output
# ```python
# Frequency count
# ```

# %%
# Write your code here
df = pd.DataFrame({
    'Name' : ['shreyash','aryan','rahul','ayan','ani'],
    'Marks' : [50, 30, 80, 50, 70],
    'City' : ['bhopal', 'indore', 'bhopal', 'vidisha', 'bhopal'],
    'Age' : [19, 20 ,24, 30, 35]
    
})
print(df['City'].value_counts())
# Out:
# City
# bhopal     3
# indore     1
# vidisha    1
# Name: count, dtype: int64

# %% [markdown]
# # Q9. Group By City
#
# ## Problem Statement
# Find average marks city-wise.
#
# ## Sample Input
# ```python
# City and Marks
# ```
#
# ## Sample Output
# ```python
# Grouped result
# ```

# %%
# Write your code here
print(df.groupby('City')['Marks'].mean())
# Out:
# City
# bhopal     66.666667
# indore     30.000000
# vidisha    50.000000
# Name: Marks, dtype: float64

# %% [markdown]
# # Q10. Multiple Conditions
#
# ## Problem Statement
# Display students with Marks > 70 and Age > 20.
#
# ## Sample Input
# ```python
# Marks and Age
# ```
#
# ## Sample Output
# ```python
# Filtered rows
# ```

# %%
# Write your code here
print(df[(df['Marks'] > 70) & (df['Age'] > 20)])
# Out:
#     Name  Marks    City  Age
# 2  rahul     80  bhopal   24
